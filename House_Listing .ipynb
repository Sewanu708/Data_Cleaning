# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\OLA\Downloads\listings (1).csv',parse_dates=['last_review'])

# %%
df.head()
# Out:
#      id                                      name  host_id  host_name  \
# 0  2595                     Skylit Midtown Castle     2845   Jennifer
# 1  5121                           BlissArtsSpace!     7356      Garon
# 2  5136  Spacious Brooklyn Duplex, Patio + Garden     7378    Rebecca
# 3  5178          Large Furnished Room Near B'way　     8967   Shunichi
# 4  5203        Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2            Brooklyn         Sunset Park  40.66265  -73.99454
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4           Manhattan     Upper West Side  40.80380  -73.96751
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    225              30                 48  2019-11-04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37410 entries, 0 to 37409
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              37410 non-null  int64
#  1   name                            37396 non-null  object
#  2   host_id                         37410 non-null  int64
#  3   host_name                       37344 non-null  object
#  4   neighbourhood_group             37410 non-null  object
#  5   neighbourhood                   37410 non-null  object
#  6   latitude                        37410 non-null  float64
#  7   longitude                       37410 non-null  float64
#  8   room_type                       37410 non-null  object
#  9   price                           37410 non-null  int64
#  10  minimum_nights                  37410 non-null  int64
#  11  number_of_reviews               37410 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 14
# host_id                               0
# host_name                            66
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        7949
# reviews_per_month                  7949
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           37406
# dtype: int64

# %%
df.count()
# Out:
# id                                37410
# name                              37396
# host_id                           37410
# host_name                         37344
# neighbourhood_group               37410
# neighbourhood                     37410
# latitude                          37410
# longitude                         37410
# room_type                         37410
# price                             37410
# minimum_nights                    37410
# number_of_reviews                 37410
# last_review                       29461
# reviews_per_month                 29461
# calculated_host_listings_count    37410
# availability_365                  37410
# number_of_reviews_ltm             37410
# license                               4
# dtype: int64

# %%
#dropping column license
#df.drop(labels='license',inplace=True,axis=1)
df.drop(labels=['longitude','latitude'],inplace=True,axis=1)

# %%
df.head()
# Out:
#      id                                      name  host_id  host_name  \
# 0  2595                     Skylit Midtown Castle     2845   Jennifer
# 1  5121                           BlissArtsSpace!     7356      Garon
# 2  5136  Spacious Brooklyn Duplex, Patio + Garden     7378    Rebecca
# 3  5178          Large Furnished Room Near B'way　     8967   Shunichi
# 4  5203        Cozy Clean Guest Room - Family Apt     7490  MaryEllen
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75356  -73.98559
# 1            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 2            Brooklyn         Sunset Park  40.66265  -73.99454
# 3           Manhattan             Midtown  40.76457  -73.98317
# 4           Manhattan     Upper West Side  40.80380  -73.96751
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    225              30                 48  2019-11-04
# ...

# %%
df[df.name.isnull()]
# Out:
#              id name    host_id host_name neighbourhood_group  \
# 1847    2232600  NaN   11395220      Anna           Manhattan
# 2907    4209595  NaN   20700823     Jesse           Manhattan
# 3105    4370230  NaN   22686810   Michaël           Manhattan
# 3147    4581788  NaN   21600904     Lucie            Brooklyn
# 3371    4756856  NaN    1832442  Carolina            Brooklyn
# 3437    4774658  NaN   24625694      Josh           Manhattan
# 4435    6782407  NaN   31147528  Huei-Yin            Brooklyn
# 6070    9325951  NaN   33377685  Jonathan           Manhattan
# 6545    9787590  NaN   50448556    Miguel           Manhattan
# 6761   10052289  NaN   49522403   Vanessa            Brooklyn
# 6927   10116081  NaN   51913270    Andrew           Manhattan
# 8112   12797684  NaN   69715276       Yan           Manhattan
# 8201   12988898  NaN   71552588    Andrea               Bronx
# 12237  21044649  NaN  151547086     Tanya               Bronx
#
# ...

# %%
#imputation
neighbourhood=df["neighbourhood"].unique()
for i in neighbourhood:
    #of= 
    avg=df[df['neighbourhood']==i]['reviews_per_month'].mean()
    df.loc[(df['neighbourhood']==i) & (df['reviews_per_month'].isnull()),"reviews_per_month"]=avg

# %%
df[df.reviews_per_month.isnull()].neighbourhood.unique()
# Out:
# array(['Fort Wadsworth', 'New Dorp', 'Pelham Islands',
#        'LaGuardia Airport'], dtype=object)

# %%
for i in nei:
    #of= 
    df.loc[(df['neighbourhood']==i) & (df['reviews_per_month'].isnull()),"reviews_per_month"]=0

# %%
df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
df.last_review.isnull().sum()
# Out:
# 7949

# %%
df.drop('last review',axis=1,inplace=True)

# %%
for j in neighbourhood:
    avg=df[(df['neighbourhood']==j)]['last_review'].mean()
    df.loc[((df['neighbourhood']==j) & (df.last_review.isnull())),'last_review']=avg

# %%
df['last_review'].isnull().sum()
# Out:
# 4

# %%
df['last_review'].fillna(0,inplace=True)

# %%
df['last_review'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                              14
# host_id                            0
# host_name                         66
# neighbourhood_group                0
# neighbourhood                      0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# number_of_reviews_ltm              0
# dtype: int64

# %%
df.drop_duplicates(subset='id',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %%
df.to_csv(r'C:\Users\OLA\Desktop\house listing.csv',index=False)
